# %%
# general overview= board, display board, play game, handle turn, check win/rows/col/diagnosis/tie, flip player

# %%
# Global var
# simple list for board game
board = ["-","-","-",
         "-","-","-",
         "-","-","-"]

# if game still goin on
game_still_going = True

# who won or tie?
winner = None

# whos turn is it?
current_player = "X"

# fn to define display board
def display_board():
    print(board[0] + " | " + board[1] + " | " + board[2])
    print(board[3] + " | " + board[4] + " | " + board[5])
    print(board[6] + " | " + board[7] + " | " + board[8])

def play_game():
    
    
    display_board() # call the function for display the board  
    
    while game_still_going:
        
        handle_turn(current_player)
        
        check_if_game_over()
        
        flip_player()
     
    # the game has ended
    if winner == "X" or winner == "0":
        print(winner + " won.")
    elif winner == None:
        print("Tie.")
         
# handle single turn of an arbitrary player    
def handle_turn(player):
    print(player + "'s turn.")
    position = input("Choose a position from 1-9: ")
    
    valid = False
    while not valid:

        # need while loop until it gives the correct position until its range between 1-9, not if statement
        while position not in ["1", "2", "3", "4", "5", "6", "7", "8", "9"]:
            position = input("Invalid input. Choose a position from 1-9: ")


        position = int(position) -1

        if board[position] == "-":
            valid = True
        else:
            print("You can't go there. Try again.")
    
    board[position] = player
    display_board()
    
def check_if_game_over():
    check_for_winner()
    check_if_tie()
    
def check_for_winner():
    # set up global var
    global winner
    
    # check rows/col/diagnonals
    row_winner = check_rows()
    column_winner = check_columns()
    diagonal_winner = check_diagonals()
    if row_winner:
        winner = row_winner
    elif column_winner:
        winner = column_winner
    elif diagonal_winner:
        winner = diagonal_winner
    else:
        # there was no win
        winner = None
    return

def check_rows():
    global game_still_going
    # check if an of the rows have all the same val or empty
    row_1 = board[0] == board[1] == board[2] != "-"
    row_2 = board[3] == board[4] == board[5] != "-"
    row_3 = board[6] == board[7] == board[8] != "-"
    # if an row does have a match, flag that there is a win
    if row_1 or row_2 or row_3:
        game_still_going = False
    if row_1:
        return board[0]
    elif row_2:
        return board[3]
    elif row_3:
        return board[6]
    return

def check_columns():
    global game_still_going
    # check if an of the rows have all the same val or empty
    column_1 = board[0] == board[3] == board[6] != "-"
    column_2 = board[1] == board[4] == board[7] != "-"
    column_3 = board[2] == board[5] == board[8] != "-"
    # if an column does have a match, flag that there is a win
    if column_1 or column_2 or column_3:
        game_still_going = False
    if column_1:
        return board[0]
    elif column_2:
        return board[1]
    elif column_3:
        return board[2]
    return

def check_diagonals():
    global game_still_going
    # check if an of the rows have all the same val or empty
    diagonals_1 = board[0] == board[4] == board[8] != "-"
    diagonals_2 = board[6] == board[4] == board[2] != "-"
    # if an rdiagonal does have a match, flag that there is a win
    if diagonals_1 or diagonals_2:
        game_still_going = False
    if diagonals_1:
        return board[0]
    elif diagonals_2:
        return board[6]
    return

def check_if_tie():
    global game_still_going
    if "-" not in board:
        game_still_going = False
    return

def flip_player():
    global current_player
    # if the current player was x then change it to zero and vice versa
    if current_player == "X":
        current_player = "0"
    elif current_player == "0":
        current_player = "X"
    return
    
    
play_game()
# Out:
# - | - | -
# - | - | -
# - | - | -
# X's turn.
# Choose a position from 1-9: 3
# - | - | X
# - | - | -
# - | - | -
# 0's turn.
# Choose a position from 1-9: 4
# - | - | X
# 0 | - | -
# - | - | -
# X's turn.
# Choose a position from 1-9: 6
# - | - | X
# 0 | - | X
# - | - | -
# 0's turn.
# Choose a position from 1-9: 2
# - | 0 | X
# 0 | - | X
# - | - | -
# X's turn.
# Choose a position from 1-9: 8
# - | 0 | X
# 0 | - | X
# - | X | -
# 0's turn.
# Choose a position from 1-9: 5
# - | 0 | X
# 0 | 0 | X
# - | X | -
# X's turn.
# Choose a position from 1-9: 9
# - | 0 | X
# 0 | 0 | X
# - | X | X
# X won.
